# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
ship = sb.load_dataset('titanic')
df1 = sb.load_dataset("tips")

# %%
rows, cols = df1.shape
print('number of rows: ', rows)
print('number of cols: ', cols)
# Out:
# number of rows:  244
# number of cols:  7

# %%
# data structure
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# step 3 
# finding missing values
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
ship.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
percentage1 = df1.isnull().sum() /df1.shape[0] * 100
percentage2 = ship.isnull().sum() /ship.shape[0] * 100
print(percentage1)
print(percentage2)
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# type castng
# to convert into different data type
# city[['males', 'females']] = city[['males', 'females']].astype('int64') ## bool, str, float

# %%
# summary statistics
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
ship.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# value count of a specific column
df1['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
# deal with duplicates
ship[ship.embark_town == 'Queenstown'] # sirf queenstown walon ka data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 16          0       3    male   2.0      4      1  29.1250        Q  Third
# 22          1       3  female  15.0      0      0   8.0292        Q  Third
# 28          1       3  female   NaN      0      0   7.8792        Q  Third
# 32          1       3  female   NaN      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 790         0       3    male   NaN      0      0   7.7500        Q  Third
# 825         0       3    male   NaN      0      0   6.9500        Q  Third
# 828         1       3    male   NaN      0      0   7.7500        Q  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
sb.histplot(ship['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# to find skewness and kurtosis
ship['age'].agg(['skew', 'kurtosis'])
# Out:
# skew        0.389108
# kurtosis    0.178274
# Name: age, dtype: float64

# %%
# corelation
corr = df1.corr(method='pearson')
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
corr1 = ship.corr(method='spearman')
corr1
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.339668 -0.052565  0.088879  0.138266  0.323736
# pclass     -0.339668  1.000000 -0.361666 -0.043019 -0.022801 -0.688032
# age        -0.052565 -0.361666  1.000000 -0.182061 -0.254212  0.135051
# sibsp       0.088879 -0.043019 -0.182061  1.000000  0.450014  0.447113
# parch       0.138266 -0.022801 -0.254212  0.450014  1.000000  0.410074
# fare        0.323736 -0.688032  0.135051  0.447113  0.410074  1.000000
# adult_male -0.557080  0.099351  0.257641 -0.307948 -0.397286 -0.308894
# alone      -0.203367  0.135896  0.167293 -0.828215 -0.683719 -0.531472
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.099351  0.135896
# age           0.257641  0.167293
# sibsp        -0.307948 -0.828215
# parch        -0.397286 -0.683719
# fare         -0.308894 -0.531472
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sb.heatmap(corr1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# age data bohat bara hai to
# df = df.sample(1000) # for example
